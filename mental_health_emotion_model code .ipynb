# %%
# !pip install -q transformers datasets torch scikit-learn pandas shap lime

import os, re
os.environ["WANDB_DISABLED"] = "true"

import pandas as pd
import torch
from sklearn.model_selection import train_test_split
from torch.utils.data import Dataset
from transformers import (
    DistilBertTokenizerFast,
    DistilBertForSequenceClassification,
    Trainer,
    TrainingArguments
)
from sklearn.metrics import f1_score
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 275.7/275.7 kB 9.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for lime (setup.py) ... done

# %%
# If file is in /content directly
df = pd.read_csv('/content/go_emotions_dataset.csv')

def clean_text(text):
    text = str(text)
    text = re.sub(r'[^\w\s]', '', text)
    text = re.sub(r'\s+', ' ', text)
    return text.lower().strip()

df['clean_text'] = df['text'].apply(clean_text)

non_label_cols = ['id', 'text', 'example_very_unclear', 'clean_text']
label_cols = [c for c in df.columns if c not in non_label_cols]

train_df, temp_df = train_test_split(df, test_size=0.2, random_state=42)
val_df, test_df = train_test_split(temp_df, test_size=0.5, random_state=42)

# %%
tokenizer = DistilBertTokenizerFast.from_pretrained('distilbert-base-uncased')
max_length = 128

class GoEmotionsDataset(Dataset):
    def __init__(self, dataframe, tokenizer, label_cols, max_length):
        self.texts = dataframe['clean_text'].tolist()
        self.labels = dataframe[label_cols].values.astype(float)
        self.tokenizer = tokenizer
        self.max_length = max_length

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, idx):
        text = self.texts[idx]
        labels = torch.tensor(self.labels[idx], dtype=torch.float)
        encoding = self.tokenizer(
            text,
            max_length=self.max_length,
            padding='max_length',
            truncation=True,
            return_tensors='pt'
        )
        item = {k: v.squeeze(0) for k, v in encoding.items()}
        item['labels'] = labels
        return item

train_dataset = GoEmotionsDataset(train_df, tokenizer, label_cols, max_length)
val_dataset   = GoEmotionsDataset(val_df, tokenizer, label_cols, max_length)
test_dataset  = GoEmotionsDataset(test_df, tokenizer, label_cols, max_length)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/483 [00:00<?, ?B/s]

# %%
model = DistilBertForSequenceClassification.from_pretrained(
    'distilbert-base-uncased',
    num_labels=len(label_cols),
    problem_type="multi_label_classification"
)

def compute_metrics(eval_pred):
    logits, labels = eval_pred
    probs = torch.sigmoid(torch.tensor(logits))
    preds = (probs > 0.5).int().numpy()
    labels = labels.astype(int)
    micro_f1 = f1_score(labels, preds, average='micro')
    return {'micro_f1': micro_f1}

training_args = TrainingArguments(
    output_dir='./results',
    eval_strategy='epoch',          # <-- change this line
    save_strategy='epoch',
    per_device_train_batch_size=8,
    per_device_eval_batch_size=16,
    num_train_epochs=3,
    logging_dir='./logs',
    logging_steps=50,
    load_best_model_at_end=True,
    metric_for_best_model='micro_f1'
)


trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
    compute_metrics=compute_metrics,
    tokenizer=tokenizer
)

trainer.train()
# Out:
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# /tmp/ipython-input-3056716330.py:29: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
#     <div>
#
#       <progress value='63369' max='63369' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [63369/63369 1:43:33, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Micro F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.115100</td>
#       <td>0.113800</td>
#       <td>0.311430</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.107300</td>
#       <td>0.111903</td>
#       <td>0.351822</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.098700</td>
#       <td>0.113611</td>
#       <td>0.369399</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=63369, training_loss=0.10964590572442118, metrics={'train_runtime': 6214.714, 'train_samples_per_second': 81.571, 'train_steps_per_second': 10.197, 'total_flos': 1.679604003108864e+16, 'train_loss': 0.10964590572442118, 'epoch': 3.0})

# %%
# Test set evaluation (run this after training)
test_results = trainer.evaluate(eval_dataset=test_dataset)
print("Full test results:", test_results)

# Also check validation results from last epoch
val_results = trainer.evaluate(eval_dataset=val_dataset)
print("Validation results:", val_results)

# %%
test_results = trainer.evaluate(eval_dataset=test_dataset)
print("Test metrics:", test_results)

# Save model + tokenizer to Drive or /content
save_path = "/content/mental_health_emotion_model"
model.save_pretrained(save_path)
tokenizer.save_pretrained(save_path)
# Out:
#     <div>
#
#       <progress value='1321' max='1321' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1321/1321 01:15]
#     </div>
# Test metrics: {'eval_loss': 0.11380043625831604, 'eval_micro_f1': 0.3682558907729575, 'eval_runtime': 75.259, 'eval_samples_per_second': 280.671, 'eval_steps_per_second': 17.553, 'epoch': 3.0}
# ('/content/mental_health_emotion_model/tokenizer_config.json',
#  '/content/mental_health_emotion_model/special_tokens_map.json',
#  '/content/mental_health_emotion_model/vocab.txt',
#  '/content/mental_health_emotion_model/added_tokens.json',
#  '/content/mental_health_emotion_model/tokenizer.json')

# %%
import numpy as np

def predict_emotions(text):
    model.eval()
    inputs = tokenizer(
        text,
        return_tensors='pt',
        truncation=True,
        padding='max_length',
        max_length=128
    )
    device = next(model.parameters()).device
    inputs = {k: v.to(device) for k, v in inputs.items()}
    with torch.no_grad():
        outputs = model(**inputs)
        logits = outputs.logits
        probs = torch.sigmoid(logits).cpu().numpy()[0]

    predicted_indices = np.where(probs > 0.5)[0]
    predicted_emotions = [label_cols[i] for i in predicted_indices]
    predicted_scores   = [float(probs[i]) for i in predicted_indices]
    return list(zip(predicted_emotions, predicted_scores))

emotion_to_risk = {
    'admiration': 'low', 'amusement': 'low', 'anger': 'high',
    'annoyance': 'moderate', 'approval': 'low', 'caring': 'low',
    'confusion': 'moderate', 'curiosity': 'low', 'desire': 'low',
    'disappointment': 'moderate', 'disapproval': 'moderate',
    'disgust': 'high', 'embarrassment': 'moderate', 'excitement': 'low',
    'fear': 'high', 'gratitude': 'low', 'grief': 'high', 'joy': 'low',
    'love': 'low', 'nervousness': 'moderate', 'optimism': 'low',
    'pride': 'low', 'realization': 'low', 'relief': 'low',
    'remorse': 'high', 'sadness': 'high', 'surprise': 'low',
    'neutral': 'low'
}

def map_risk(predictions):
    risks = [emotion_to_risk.get(emotion, 'low') for emotion, _ in predictions]
    if 'high' in risks:
        return 'high'
    elif 'moderate' in risks:
        return 'moderate'
    else:
        return 'low'

sample_text = "Feeling anxious and overwhelmed today"
preds = predict_emotions(sample_text)
print("Predictions:", preds)
print("Risk level:", map_risk(preds))
# Out:
# Predictions: [('nervousness', 0.7248819470405579)]
# Risk level: moderate

# %%
from transformers import pipeline
from lime.lime_text import LimeTextExplainer
import shap

nlp_pipe = pipeline(
    'text-classification',
    model=model,
    tokenizer=tokenizer,
    return_all_scores=True
)

def lime_predict(texts):
    outputs = nlp_pipe(texts)
    probs = np.array([[item['score'] for item in out] for out in outputs])
    return probs

lime_explainer = LimeTextExplainer(class_names=label_cols)

example_text = "I'm feeling really anxious and sad today."
lime_exp = lime_explainer.explain_instance(
    example_text,
    lime_predict,
    num_features=10,
    top_labels=3
)
top_label = lime_exp.top_labels[0]
print("Top label:", label_cols[top_label])
print(lime_exp.as_list(label=top_label))

shap_explainer = shap.Explainer(nlp_pipe)
shap_values = shap_explainer([example_text])
shap.plots.text(shap_values[0])
# Out:
# Device set to use cuda:0
# /usr/local/lib/python3.12/dist-packages/transformers/pipelines/text_classification.py:111: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
# Top label: nervousness
# [(np.str_('anxious'), 0.6257619330360809), (np.str_('sad'), -0.0689724105017361), (np.str_('I'), 0.06081926320608145), (np.str_('m'), 0.02134293635201155), (np.str_('really'), 0.019081201591422667), (np.str_('feeling'), 0.01542034509586995), (np.str_('and'), 0.011517499406790402), (np.str_('today'), 0.0026100527111543553)]
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# <div align='center'>
# <script>
#     document._hover_qahftrxckafnafqofpva = '_tp_qahftrxckafnafqofpva_output_0';
#     document._zoom_qahftrxckafnafqofpva = undefined;
#     function _output_onclick_qahftrxckafnafqofpva(i) {
#         var next_id = undefined;
#
#         if (document._zoom_qahftrxckafnafqofpva !== undefined) {
#             document.getElementById(document._zoom_qahftrxckafnafqofpva+ '_zoom').style.display = 'none';
#
#             if (document._zoom_qahftrxckafnafqofpva === '_tp_qahftrxckafnafqofpva_output_' + i) {
#                 document.getElementById(document._zoom_qahftrxckafnafqofpva).style.display = 'block';
#                 document.getElementById(document._zoom_qahftrxckafnafqofpva+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_qahftrxckafnafqofpva).style.display = 'none';
#                 document.getElementById(document._zoom_qahftrxckafnafqofpva+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_qahftrxckafnafqofpva !== '_tp_qahftrxckafnafqofpva_output_' + i) {
#             next_id = '_tp_qahftrxckafnafqofpva_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_qahftrxckafnafqofpva = next_id;
#     }
#     function _output_onmouseover_qahftrxckafnafqofpva(i, el) {
#         if (document._zoom_qahftrxckafnafqofpva !== undefined) { return; }
#         if (document._hover_qahftrxckafnafqofpva !== undefined) {
#             document.getElementById(document._hover_qahftrxckafnafqofpva + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_qahftrxckafnafqofpva).style.display = 'none';
#         }
#         document.getElementById('_tp_qahftrxckafnafqofpva_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_qahftrxckafnafqofpva = '_tp_qahftrxckafnafqofpva_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(np.float64(230.2941176470614), np.float64(26.505882352939775), np.float64(102.59215686274348), np.float64(0.0)); border-radius: 3px; padding: 0px" id="_tp_qahftrxckafnafqofpva_output_0_name"
#     onclick="_output_onclick_qahftrxckafnafqofpva(0)"
#     onmouseover="_output_onmouseover_qahftrxckafnafqofpva(0, this);">LABEL_0</div>
# <div style="display: inline; border-bottom: none; background: rgba(np.float64(230.2941176470614), np.float64(26.505882352939775), np.float64(102.59215686274348), np.float64(0.0)); border-radius: 3px; padding: 0px" id="_tp_qahftrxckafnafqofpva_output_1_name"
#     onclick="_output_onclick_qahftrxckafnafqofpva(1)"
#     onmouseover="_output_onmouseover_qahftrxckafnafqofpva(1, this);">LABEL_1</div>
# <div style="display: inline; border-bottom: none; background: rgba(np.float64(230.2941176470614), np.float64(26.505882352939775), np.float64(102.59215686274348), np.float64(0.0)); border-radius: 3px; padding: 0px" id="_tp_qahftrxckafnafqofpva_output_2_name"
#     onclick="_output_onclick_qahftrxckafnafqofpva(2)"
#     onmouseover="_output_onmouseover_qahftrxckafnafqofpva(2, this);">LABEL_2</div>
# <div style="display: inline; border-bottom: none; background: rgba(np.float64(255.0), np.float64(13.0), np.float64(87.0), np.float64(0.02253911665676371)); border-radius: 3px; padding: 0px" id="_tp_qahftrxckafnafqofpva_output_3_name"
#     onclick="_output_onclick_qahftrxckafnafqofpva(3)"
#     onmouseover="_output_onmouseover_qahftrxckafnafqofpva(3, this);">LABEL_3</div>
# <div style="display: inline; border-bottom: none; background: rgba(np.float64(255.0), np.float64(13.0), np.float64(87.0), np.float64(0.014656367597544035)); border-radius: 3px; padding: 0px" id="_tp_qahftrxckafnafqofpva_output_4_name"
#     onclick="_output_onclick_qahftrxckafnafqofpva(4)"
#     onmouseover="_output_onmouseover_qahftrxckafnafqofpva(4, this);">LABEL_4</div>
# <div style="display: inline; border-bottom: none; background: rgba(np.float64(255.0), np.float64(13.0), np.float64(87.0), np.float64(0.014656367597544035)); border-radius: 3px; padding: 0px" id="_tp_qahftrxckafnafqofpva_output_5_name"
#     onclick="_output_onclick_qahftrxckafnafqofpva(5)"
#     onmouseover="_output_onmouseover_qahftrxckafnafqofpva(5, this);">LABEL_5</div>
# <div style="display: inline; border-bottom: none; background: rgba(np.float64(255.0), np.float64(13.0), np.float64(87.0), np.float64(0.00677361853832443)); border-radius: 3px; padding: 0px" id="_tp_qahftrxckafnafqofpva_output_6_name"
#     onclick="_output_onclick_qahftrxckafnafqofpva(6)"
#     onmouseover="_output_onmouseover_qahftrxckafnafqofpva(6, this);">LABEL_6</div>
# <div style="display: inline; border-bottom: none; background: rgba(np.float64(255.0), np.float64(13.0), np.float64(87.0), np.float64(0.030421865715983164)); border-radius: 3px; padding: 0px" id="_tp_qahftrxckafnafqofpva_output_7_name"
#     onclick="_output_onclick_qahftrxckafnafqofpva(7)"
#     onmouseover="_output_onmouseover_qahftrxckafnafqofpva(7, this);">LABEL_7</div>
# <div style="display: inline; border-bottom: none; background: rgba(np.float64(230.2941176470614), np.float64(26.505882352939775), np.float64(102.59215686274348), np.float64(0.0)); border-radius: 3px; padding: 0px" id="_tp_qahftrxckafnafqofpva_output_8_name"
#     onclick="_output_onclick_qahftrxckafnafqofpva(8)"
#     onmouseover="_output_onmouseover_qahftrxckafnafqofpva(8, this);">LABEL_8</div>
# <div style="display: inline; border-bottom: none; background: rgba(np.float64(255.0), np.float64(13.0), np.float64(87.0), np.float64(0.14078035254505847)); border-radius: 3px; padding: 0px" id="_tp_qahftrxckafnafqofpva_output_9_name"
#     onclick="_output_onclick_qahftrxckafnafqofpva(9)"
#     onmouseover="_output_onmouseover_qahftrxckafnafqofpva(9, this);">LABEL_9</div>
# <div style="display: inline; border-bottom: none; background: rgba(np.float64(255.0), np.float64(13.0), np.float64(87.0), np.float64(0.00677361853832443)); border-radius: 3px; padding: 0px" id="_tp_qahftrxckafnafqofpva_output_10_name"
#     onclick="_output_onclick_qahftrxckafnafqofpva(10)"
#     onmouseover="_output_onmouseover_qahftrxckafnafqofpva(10, this);">LABEL_10</div>
# <div style="display: inline; border-bottom: none; background: rgba(np.float64(230.2941176470614), np.float64(26.505882352939775), np.float64(102.59215686274348), np.float64(0.0)); border-radius: 3px; padding: 0px" id="_tp_qahftrxckafnafqofpva_output_11_name"
#     onclick="_output_onclick_qahftrxckafnafqofpva(11)"
#     onmouseover="_output_onmouseover_qahftrxckafnafqofpva(11, this);">LABEL_11</div>
# <div style="display: inline; border-bottom: none; background: rgba(np.float64(255.0), np.float64(13.0), np.float64(87.0), np.float64(0.00677361853832443)); border-radius: 3px; padding: 0px" id="_tp_qahftrxckafnafqofpva_output_12_name"
#     onclick="_output_onclick_qahftrxckafnafqofpva(12)"
#     onmouseover="_output_onmouseover_qahftrxckafnafqofpva(12, this);">LABEL_12</div>
# <div style="display: inline; border-bottom: none; background: rgba(np.float64(255.0), np.float64(13.0), np.float64(87.0), np.float64(0.00677361853832443)); border-radius: 3px; padding: 0px" id="_tp_qahftrxckafnafqofpva_output_13_name"
#     onclick="_output_onclick_qahftrxckafnafqofpva(13)"
#     onmouseover="_output_onmouseover_qahftrxckafnafqofpva(13, this);">LABEL_13</div>
# <div style="display: inline; border-bottom: none; background: rgba(np.float64(255.0), np.float64(13.0), np.float64(87.0), np.float64(0.24325609031491383)); border-radius: 3px; padding: 0px" id="_tp_qahftrxckafnafqofpva_output_14_name"
#     onclick="_output_onclick_qahftrxckafnafqofpva(14)"
#     onmouseover="_output_onmouseover_qahftrxckafnafqofpva(14, this);">LABEL_14</div>
# <div style="display: inline; border-bottom: none;
